# %% [markdown]
# # This script contains the following:
# 1. Importing libraries and data
# 2. Data cleaning¶
# 3. Data prep for regression analysis
# 4. Regression analysis
# Bonus: performance improvement after removing outliers

# %% [markdown]
# # import data and libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# %matplotlib inline

# %%
#folder shortcut
path = r'C:\Users\hp\Documents\Citi Bike'

# %%
citi = pd.read_csv(os.path.join(path, '02 Data','prepared data', 'citi_5.csv'), index_col = False)

# %%
station =pd.read_csv(os.path.join(path, '02 Data','prepared data', 'bike_station.csv'), index_col = False)

# %%
station.head()
# Out:
#    Unnamed: 0  start_station_id  start_station_latitude  \
# 0           0                72               40.767272
# 1           1                79               40.719116
# 2           2                82               40.711174
# 3           3                83               40.683826
# 4           4               116               40.741776
#
#    start_station_longitude  average_daily_rides
# 0               -73.993929             5.642857
# 1               -74.006667             4.357143
# 2               -74.000165             2.185185
# 3               -73.976323             2.571429
# 4               -74.001497             8.966667

# %%
columns_to_drop_1=['Unnamed: 0']

# %%
station
# Out:
#      Unnamed: 0  start_station_id  start_station_latitude  \
# 0             0                72               40.767272
# 1             1                79               40.719116
# 2             2                82               40.711174
# 3             3                83               40.683826
# 4             4               116               40.741776
# ..          ...               ...                     ...
# 325         325              2017               40.750224
# 326         326              2021               40.759291
# 327         327              2022               40.758491
# 328         328              2023               40.759681
# 329         329              3002               40.711512
#
#      start_station_longitude  average_daily_rides
# 0                 -73.993929             5.642857
# 1                 -74.006667             4.357143
# 2                 -74.000165             2.185185
# 3                 -73.976323             2.571429
# 4                 -74.001497             8.966667
# ..                       ...                  ...
# 325               -73.971214             3.000000
# 326               -73.988597             5.357143
# 327               -73.959206             3.310345
# 328               -73.970314             3.217391
# 329               -74.015756             6.766667
#
# [330 rows x 5 columns]

# %%
citi.columns
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'day_of_week',
#        'start_hour', 'start_station_id', 'start_station_name',
#        'start_station_latitude', 'start_station_longitude', 'end_station_id',
#        'end_station_name', 'end_station_latitude', 'end_station_longitude',
#        'trip_duration', 'subscriber', 'birth_year', 'gender', 'ride_start',
#        'ride_end', 'Trip category', 'ride_start_date', 'ride_start_time'],
#       dtype='object')

# %%
#getting rid of un needed columns
citi_1=citi[['day_of_week','start_hour',
       'start_station_id', 'start_station_name', 'start_station_latitude',
       'start_station_longitude', 'end_station_id', 'end_station_name',
       'end_station_latitude', 'end_station_longitude', 'trip_duration',
       'subscriber', 'birth_year', 'gender', 'ride_start', 'ride_end',
       'Trip category', 'ride_start_date', 'ride_start_time']]

# %%
citi_1
# Out:
#       day_of_week  start_hour  start_station_id       start_station_name  \
# 0             Mon          18               523          W 38 St & 8 Ave
# 1             Thu          18               257  Lispenard St & Broadway
# 2             Wed          19               479          9 Ave & W 45 St
# 3             Sat          11               527          E 33 St & 1 Ave
# 4             Fri          22               293    Lafayette St & E 8 St
# ...           ...         ...               ...                      ...
# 42988         Sat          15               435          W 21 St & 6 Ave
# 42989         Sun          16               224    Spruce St & Nassau St
# 42990         Sat          17               261     Johnson St & Gold St
# 42991         Sat          18               402       Broadway & E 22 St
# 42992         Mon          21               515         W 43 St & 10 Ave
#
#        start_station_latitude  start_station_longitude  end_station_id  \
# 0                   40.754666               -73.991382             334
# 1                   40.719392               -74.002472             236
# 2                   40.760193               -73.991255             513
# 3                   40.743156               -73.974347             441
# 4                   40.730287               -73.990765             432
# ...                       ...                      ...             ...
# 42988               40.741740               -73.994156             448
# 42989               40.711464               -74.005524             301
# 42990               40.694749               -73.983625             151
# 42991               40.740343               -73.989551             524
# 42992               40.760094               -73.994618             488
#
#                end_station_name  end_station_latitude  end_station_longitude  \
# 0               W 20 St & 7 Ave             40.742388             -73.997262
# 1           St Marks Pl & 2 Ave             40.728419             -73.987140
# 2              W 56 St & 10 Ave             40.768254             -73.988639
# 3               E 52 St & 2 Ave             40.756014             -73.967416
# 4             E 7 St & Avenue A             40.726218             -73.983799
# ...                         ...                   ...                    ...
# 42988          W 37 St & 10 Ave             40.756604             -73.997901
# 42989         E 2 St & Avenue B             40.722174             -73.983688
# 42990  Cleveland Pl & Spring St             40.721816             -73.997203
# 42991           W 43 St & 6 Ave             40.755273             -73.983169
# 42992           W 39 St & 9 Ave             40.756458             -73.993722
#
#        trip_duration  subscriber  birth_year  gender           ride_start  \
# 0                993  Subscriber      1968.0       2  2013-09-09 18:18:55
# 1                581  Subscriber      1983.0       1  2013-09-12 18:38:53
# 2                361  Subscriber      1989.0       1  2013-09-18 19:44:04
# 3                561  Subscriber      1988.0       2  2013-09-28 11:54:37
# 4                427  Subscriber      1986.0       2  2013-09-27 22:01:01
# ...              ...         ...         ...     ...                  ...
# 42988            975  Subscriber      1973.0       1  2013-09-28 15:30:14
# 42989           1541  Subscriber      1975.0       1  2013-09-01 16:27:11
# 42990           1191  Subscriber      1970.0       2  2013-09-14 17:32:26
# 42991           1050  Subscriber      1961.0       2  2013-09-07 18:08:21
# 42992            370  Subscriber      1980.0       2  2013-09-23 21:54:36
#
#                   ride_end     Trip category ride_start_date ride_start_time
# 0      2013-09-09 18:35:28     10-20 minutes      2013-09-09        18:18:55
# 1      2013-09-12 18:48:34  under 10 minutes      2013-09-12        18:38:53
# 2      2013-09-18 19:50:05  under 10 minutes      2013-09-18        19:44:04
# 3      2013-09-28 12:03:58  under 10 minutes      2013-09-28        11:54:37
# 4      2013-09-27 22:08:08  under 10 minutes      2013-09-27        22:01:01
# ...                    ...               ...             ...             ...
# 42988  2013-09-28 15:46:29     10-20 minutes      2013-09-28        15:30:14
# 42989  2013-09-01 16:52:52   over 20 minutes      2013-09-01        16:27:11
# 42990  2013-09-14 17:52:17     10-20 minutes      2013-09-14        17:32:26
# 42991  2013-09-07 18:25:51     10-20 minutes      2013-09-07        18:08:21
# 42992  2013-09-23 22:00:46  under 10 minutes      2013-09-23        21:54:36
#
# [42993 rows x 19 columns]

# %% [markdown]
# # clean data - look for outliers extreme values

# %%
citi_1.describe()
# Out:
#          start_hour  start_station_id  start_station_latitude  \
# count  42993.000000      42993.000000            42993.000000
# mean      14.085316        437.205545               40.734477
# std        4.932889        340.848654                0.019598
# min        0.000000         72.000000               40.680342
# 25%       10.000000        304.000000               40.721101
# 50%       15.000000        402.000000               40.736245
# 75%       18.000000        485.000000               40.749718
# max       23.000000       3002.000000               40.770513
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count             42993.000000    42993.000000          42993.000000
# mean                -73.990948      434.577094             40.734070
# std                   0.012367      332.801118              0.019603
# min                 -74.017134       72.000000             40.680342
# 25%                 -74.000040      305.000000             40.720828
# 50%                 -73.990765      402.000000             40.735877
# 75%                 -73.981948      483.000000             40.749013
# max                 -73.950048     3002.000000             40.770513
#
#        end_station_longitude  trip_duration    birth_year        gender
# count           42993.000000   42993.000000  42993.000000  42993.000000
# mean              -73.991242     770.502105   1975.674459      1.247854
# std                 0.012375     523.444233     10.938735      0.431880
# min               -74.017134      60.000000   1924.000000      0.000000
# 25%               -74.000271     395.000000   1968.000000      1.000000
# 50%               -73.990985     621.000000   1978.000000      1.000000
# 75%               -73.982578     999.000000   1984.000000      1.000000
# max               -73.950048    2697.000000   1997.000000      2.000000

# %%
sns.distplot(citi_1['trip_duration'], bins=60) # Shows extreme values
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7928\1648765124.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(citi_1['trip_duration'], bins=60) # Shows extreme values
# <Axes: xlabel='trip_duration', ylabel='Density'>

# %%
# Define data types for specific columns
data_types = {
    'ride_start_date': 'datetime64'
}

# %%
file_path = os.path.join(path, '02 Data','prepared data','citi_5.csv')

# %%
parse_dates = ['ride_start_date']

# %%
citi_1 = pd.read_csv(file_path, parse_dates=parse_dates)

# %%
# amount of rides taken on each hour of each day
hour_counts = citi_1.groupby(['start_hour',citi_1['ride_start_date'].dt.date])['ride_start_date'].count()

# %%
hour_counts
# Out:
# start_hour  ride_start_date
# 0           2013-09-01         15
#             2013-09-02         15
#             2013-09-03          5
#             2013-09-04          9
#             2013-09-05         13
#                                ..
# 23          2013-09-26         38
#             2013-09-27         44
#             2013-09-28         48
#             2013-09-29         21
#             2013-09-30         17
# Name: ride_start_date, Length: 711, dtype: int64

# %%
# average rides per hour
avg_rides_per_hour = hour_counts.groupby('start_hour').mean().reset_index()

# %%
avg_rides_per_hour
# Out:
#     start_hour  ride_start_date
# 0            0        14.000000
# 1            1         8.866667
# 2            2         5.586207
# 3            3         3.692308
# 4            4         2.777778
# 5            5         6.724138
# 6            6        29.633333
# 7            7        66.000000
# 8            8       104.233333
# 9            9        86.600000
# 10          10        60.900000
# 11          11        61.366667
# 12          12        78.433333
# 13          13        80.266667
# 14          14        80.033333
# 15          15        81.200000
# 16          16       101.533333
# 17          17       146.600000
# 18          18       142.666667
# 19          19        97.666667
# 20          20        64.400000
# 21          21        45.700000
# 22          22        38.633333
# 23          23        26.766667

# %%
# rides per day 
day_counts = citi.groupby('day_of_week')['ride_start_date'].count()

# %%
day_counts
# Out:
# day_of_week
# Fri    6594
# Mon    6797
# Sat    4965
# Sun    5506
# Thu    6212
# Tue    6429
# Wed    6490
# Name: ride_start_date, dtype: int64

# %%
# rides per hour on each day of the week
day_hour_counts = citi_1.groupby([ 'day_of_week','start_hour'])['ride_start_date'].count()

# %%
day_hour_counts
# Out:
# day_of_week  start_hour
# Fri          0              48
#              1              36
#              2              23
#              3              10
#              4              10
#                           ...
# Wed          19            479
#              20            297
#              21            213
#              22            188
#              23            103
# Name: ride_start_date, Length: 168, dtype: int64

# %%
# Create a scatterplot using matplotlib for another look at how the chosen variables plot against each other.

citi_1.plot(x = 'start_hour', y='trip_duration',style='o') # The style option creates a scatterplot; without it, we only have lines.
plt.title('length of trip vs hour of ride')  
plt.xlabel('start_hour')  
plt.ylabel('trip_duration')  
plt.show()

# %%
# Create a scatterplot using matplotlib for another look at how the chosen variables plot against each other.

citi_1.plot(x = 'day_of_week', y='trip_duration',style='o') # The style option creates a scatterplot; without it, we only have lines.
plt.title('length of trip vs day of ride')  
plt.xlabel('day_of_week')  
plt.ylabel('trip_duration')  
plt.show()

# %%
# Create a scatterplot using matplotlib for another look at how the chosen variables plot against each other.

citi_1.plot(x = 'birth_year', y='trip_duration',style='o') # The style option creates a scatterplot; without it, we only have lines.
plt.title('length of trip vs age ')  
plt.xlabel('birth_year')  
plt.ylabel('trip_duration')  
plt.show()

# %%
# Create a scatterplot using matplotlib for another look at how the chosen variables plot against each other.

avg_rides_per_hour.plot(x = 'start_hour', y='ride_start_date',style='o') # The style option creates a scatterplot; without it, we only have lines.
plt.title('amount of rides taken vs hour ')  
plt.xlabel('start_hour')  
plt.ylabel('average_rides_taken')  
plt.show()

# %%
avg_rides_per_hour
# Out:
#     start_hour  ride_start_date
# 0            0        14.000000
# 1            1         8.866667
# 2            2         5.586207
# 3            3         3.692308
# 4            4         2.777778
# 5            5         6.724138
# 6            6        29.633333
# 7            7        66.000000
# 8            8       104.233333
# 9            9        86.600000
# 10          10        60.900000
# 11          11        61.366667
# 12          12        78.433333
# 13          13        80.266667
# 14          14        80.033333
# 15          15        81.200000
# 16          16       101.533333
# 17          17       146.600000
# 18          18       142.666667
# 19          19        97.666667
# 20          20        64.400000
# 21          21        45.700000
# 22          22        38.633333
# 23          23        26.766667

# %%
citi_1.columns
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'day_of_week',
#        'start_hour', 'start_station_id', 'start_station_name',
#        'start_station_latitude', 'start_station_longitude', 'end_station_id',
#        'end_station_name', 'end_station_latitude', 'end_station_longitude',
#        'trip_duration', 'subscriber', 'birth_year', 'gender', 'ride_start',
#        'ride_end', 'Trip category', 'ride_start_date', 'ride_start_time'],
#       dtype='object')

# %%
ride_counts = pd.get_dummies(citi_1, columns=['day_of_week', 'start_hour'], drop_first=True)

# %%
ride_counts
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  start_station_id  \
# 0                 0             0           0               523
# 1                 1             1           1               257
# 2                 2             2           2               479
# 3                 3             3           3               527
# 4                 4             4           4               293
# ...             ...           ...         ...               ...
# 42988         42988         42988       42988               435
# 42989         42989         42989       42989               224
# 42990         42990         42990       42990               261
# 42991         42991         42991       42991               402
# 42992         42992         42992       42992               515
#
#             start_station_name  start_station_latitude  \
# 0              W 38 St & 8 Ave               40.754666
# 1      Lispenard St & Broadway               40.719392
# 2              9 Ave & W 45 St               40.760193
# 3              E 33 St & 1 Ave               40.743156
# 4        Lafayette St & E 8 St               40.730287
# ...                        ...                     ...
# 42988          W 21 St & 6 Ave               40.741740
# 42989    Spruce St & Nassau St               40.711464
# 42990     Johnson St & Gold St               40.694749
# 42991       Broadway & E 22 St               40.740343
# 42992         W 43 St & 10 Ave               40.760094
#
#        start_station_longitude  end_station_id          end_station_name  \
# 0                   -73.991382             334           W 20 St & 7 Ave
# 1                   -74.002472             236       St Marks Pl & 2 Ave
# 2                   -73.991255             513          W 56 St & 10 Ave
# 3                   -73.974347             441           E 52 St & 2 Ave
# 4                   -73.990765             432         E 7 St & Avenue A
# ...                        ...             ...                       ...
# 42988               -73.994156             448          W 37 St & 10 Ave
# 42989               -74.005524             301         E 2 St & Avenue B
# 42990               -73.983625             151  Cleveland Pl & Spring St
# 42991               -73.989551             524           W 43 St & 6 Ave
# 42992               -73.994618             488           W 39 St & 9 Ave
#
#        end_station_latitude  ...  start_hour_14  start_hour_15 start_hour_16  \
# 0                 40.742388  ...          False          False         False
# 1                 40.728419  ...          False          False         False
# 2                 40.768254  ...          False          False         False
# 3                 40.756014  ...          False          False         False
# 4                 40.726218  ...          False          False         False
# ...                     ...  ...            ...            ...           ...
# 42988             40.756604  ...          False           True         False
# 42989             40.722174  ...          False          False          True
# 42990             40.721816  ...          False          False         False
# 42991             40.755273  ...          False          False         False
# 42992             40.756458  ...          False          False         False
#
#        start_hour_17  start_hour_18 start_hour_19 start_hour_20 start_hour_21  \
# 0              False           True         False         False         False
# 1              False           True         False         False         False
# 2              False          False          True         False         False
# 3              False          False         False         False         False
# 4              False          False         False         False         False
# ...              ...            ...           ...           ...           ...
# 42988          False          False         False         False         False
# 42989          False          False         False         False         False
# 42990           True          False         False         False         False
# 42991          False           True         False         False         False
# 42992          False          False         False         False          True
#
#       start_hour_22 start_hour_23
# 0             False         False
# 1             False         False
# 2             False         False
# 3             False         False
# 4              True         False
# ...             ...           ...
# 42988         False         False
# 42989         False         False
# 42990         False         False
# 42991         False         False
# 42992         False         False
#
# [42993 rows x 49 columns]

# %%
ride_counts.columns
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'start_station_id',
#        'start_station_name', 'start_station_latitude',
#        'start_station_longitude', 'end_station_id', 'end_station_name',
#        'end_station_latitude', 'end_station_longitude', 'trip_duration',
#        'subscriber', 'birth_year', 'gender', 'ride_start', 'ride_end',
#        'Trip category', 'ride_start_date', 'ride_start_time',
#        'day_of_week_Mon', 'day_of_week_Sat', 'day_of_week_Sun',
#        'day_of_week_Thu', 'day_of_week_Tue', 'day_of_week_Wed', 'start_hour_1',
#        'start_hour_2', 'start_hour_3', 'start_hour_4', 'start_hour_5',
#        'start_hour_6', 'start_hour_7', 'start_hour_8', 'start_hour_9',
#        'start_hour_10', 'start_hour_11', 'start_hour_12', 'start_hour_13',
#        'start_hour_14', 'start_hour_15', 'start_hour_16', 'start_hour_17',
#        'start_hour_18', 'start_hour_19', 'start_hour_20', 'start_hour_21',
#        'start_hour_22', 'start_hour_23'],
#       dtype='object')

# %%
# rides per hour count
rides_per_hour_count = hour_counts.groupby('start_hour').count().reset_index()

# %%
# amount of rides taken on each hour of each day
hour_counts_1 = citi_1.groupby('start_hour')['ride_start_date'].count()

# %%
hour_counts_1
# Out:
# start_hour
# 0      420
# 1      266
# 2      162
# 3       96
# 4       75
# 5      195
# 6      889
# 7     1980
# 8     3127
# 9     2598
# 10    1827
# 11    1841
# 12    2353
# 13    2408
# 14    2401
# 15    2436
# 16    3046
# 17    4398
# 18    4280
# 19    2930
# 20    1932
# 21    1371
# 22    1159
# 23     803
# Name: ride_start_date, dtype: int64

# %%
# on each hour how many rides occured and then the avg duration of those rides
hourly_aggregated = citi_1.groupby('start_hour').agg({
    'ride_start_date': 'count',          # Count of rides
    'trip_duration': 'mean'              # Average trip duration
}).reset_index()

# %%
hourly_aggregated
# Out:
#     start_hour  ride_start_date  trip_duration
# 0            0              420     748.716667
# 1            1              266     702.657895
# 2            2              162     659.561728
# 3            3               96     687.020833
# 4            4               75     667.106667
# 5            5              195     605.348718
# 6            6              889     648.613048
# 7            7             1980     727.038384
# 8            8             3127     756.595459
# 9            9             2598     728.346035
# 10          10             1827     745.684729
# 11          11             1841     760.065182
# 12          12             2353     732.083723
# 13          13             2408     748.196844
# 14          14             2401     788.499792
# 15          15             2436     784.350575
# 16          16             3046     809.883454
# 17          17             4398     822.308322
# 18          18             4280     826.911215
# 19          19             2930     782.310580
# 20          20             1932     776.412526
# 21          21             1371     771.610503
# 22          22             1159     742.789474
# 23          23              803     730.199253

# %%
#changing column names
hourly_aggregated.rename(columns={'ride_start_date': 'ride_count', 'trip_duration': 'avg_trip_duration'}, inplace=True)

# %%
hourly_aggregated
# Out:
#     start_hour  ride_count  avg_trip_duration
# 0            0         420         748.716667
# 1            1         266         702.657895
# 2            2         162         659.561728
# 3            3          96         687.020833
# 4            4          75         667.106667
# 5            5         195         605.348718
# 6            6         889         648.613048
# 7            7        1980         727.038384
# 8            8        3127         756.595459
# 9            9        2598         728.346035
# 10          10        1827         745.684729
# 11          11        1841         760.065182
# 12          12        2353         732.083723
# 13          13        2408         748.196844
# 14          14        2401         788.499792
# 15          15        2436         784.350575
# 16          16        3046         809.883454
# 17          17        4398         822.308322
# 18          18        4280         826.911215
# 19          19        2930         782.310580
# 20          20        1932         776.412526
# 21          21        1371         771.610503
# 22          22        1159         742.789474
# 23          23         803         730.199253

# %%
#plt for rides taken and hour
hourly_aggregated.plot(x = 'start_hour', y='ride_count',style='o') # The style option creates a scatterplot; without it, we only have lines.
plt.title('amount of rides taken vs hour ')  
plt.xlabel('start_hour')  
plt.ylabel('rides_taken')  
plt.show()

# %%
# plot for trip duration and by hour
hourly_aggregated.plot(x = 'start_hour', y='avg_trip_duration',style='o') # The style option creates a scatterplot; without it, we only have lines.
plt.title('avg trip duration by hour ')  
plt.xlabel('start_hour')  
plt.ylabel('avg_trip_duration')  
plt.show()

# %%
# plot for trip duration and hour but nt categorized
citi_1.plot(x = 'ride_start_time', y='trip_duration',style='o') # The style option creates a scatterplot; without it, we only have lines.
plt.title('trip duration and hour bike ride ')  
plt.xlabel('start_hour')  
plt.ylabel('trip_duration')  
plt.show()

# %%
citi_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42993 entries, 0 to 42992
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0.2             42993 non-null  int64
#  1   Unnamed: 0.1             42993 non-null  int64
#  2   Unnamed: 0               42993 non-null  int64
#  3   day_of_week              42993 non-null  object
#  4   start_hour               42993 non-null  int64
#  5   start_station_id         42993 non-null  int64
#  6   start_station_name       42993 non-null  object
#  7   start_station_latitude   42993 non-null  float64
#  8   start_station_longitude  42993 non-null  float64
#  9   end_station_id           42993 non-null  int64
#  10  end_station_name         42993 non-null  object
#  11  end_station_latitude     42993 non-null  float64
#  12  end_station_longitude    42993 non-null  float64
#  13  trip_duration            42993 non-null  int64
#  14  subscriber               42993 non-null  object
#  15  birth_year               42993 non-null  float64
#  16  gender                   42993 non-null  int64
#  17  ride_start               42993 non-null  object
#  18  ride_end                 42993 non-null  object
#  19  Trip category            42993 non-null  object
#  20  ride_start_date          42993 non-null  datetime64[ns]
#  21  ride_start_time          42993 non-null  object
# dtypes: datetime64[ns](1), float64(5), int64(8), object(8)
# memory usage: 7.2+ MB

# %%
# Define data types for specific columns
data_types = {
    'ride_start_time': 'datetime64'
}

# %%
file_path_1 = os.path.join(path, '02 Data','prepared data','citi_5.csv')

# %%
parse_dates = ['ride_start_time']

# %%
citi_1 = pd.read_csv(file_path_1, parse_dates=parse_dates)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7928\70117265.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   citi_1 = pd.read_csv(file_path_1, parse_dates=parse_dates)

# %%
citi_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42993 entries, 0 to 42992
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0.2             42993 non-null  int64
#  1   Unnamed: 0.1             42993 non-null  int64
#  2   Unnamed: 0               42993 non-null  int64
#  3   day_of_week              42993 non-null  object
#  4   start_hour               42993 non-null  int64
#  5   start_station_id         42993 non-null  int64
#  6   start_station_name       42993 non-null  object
#  7   start_station_latitude   42993 non-null  float64
#  8   start_station_longitude  42993 non-null  float64
#  9   end_station_id           42993 non-null  int64
#  10  end_station_name         42993 non-null  object
#  11  end_station_latitude     42993 non-null  float64
#  12  end_station_longitude    42993 non-null  float64
#  13  trip_duration            42993 non-null  int64
#  14  subscriber               42993 non-null  object
#  15  birth_year               42993 non-null  float64
#  16  gender                   42993 non-null  int64
#  17  ride_start               42993 non-null  object
#  18  ride_end                 42993 non-null  object
#  19  Trip category            42993 non-null  object
#  20  ride_start_date          42993 non-null  object
#  21  ride_start_time          42993 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), int64(8), object(8)
# memory usage: 7.2+ MB

# %%
citi_1.plot(x = 'ride_start_time', y='trip_duration',style='o') # The style option creates a scatterplot; without it, we only have lines.
plt.title('trip duration and hour bike ride ')  
plt.xlabel('start_hour')  
plt.ylabel('trip_duration')  
plt.show()

# %%
# rides by hour ride count and avg trip duration
hourly_aggregated = citi_1.groupby('start_hour').agg({
    'ride_start_date': 'count',          # Count of rides
    'trip_duration': 'mean'              # Average trip duration
}).reset_index()

# %%
hourly_aggregated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   start_hour       24 non-null     int64
#  1   ride_start_date  24 non-null     int64
#  2   trip_duration    24 non-null     float64
# dtypes: float64(1), int64(2)
# memory usage: 708.0 bytes

# %%
# making columns 
hourly_aggregated.rename(columns={'ride_start_date': 'ride_count', 'trip_duration': 'avg_trip_duration'}, inplace=True)

# %%
#plot for avg trip duration and ride count
hourly_aggregated.plot(x = 'ride_count', y='avg_trip_duration',style='o') # The style option creates a scatterplot; without it, we only have lines.
plt.title('ride counts and thier duration classified by hour ')  
plt.xlabel('ride_count')  
plt.ylabel('avg_trip_duration')  
plt.show()

# %% [markdown]
# # during busier hours where rides more often occur, the long the rides are

# %%
#using iqr method to look for outliers

# %%
q1=hourly_aggregated['ride_count'].quantile(0.25)#first Quartile
q3=hourly_aggregated['ride_count'].quantile(0.75)#third Quartile
iqr = q3-q1

# %%
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# %%
outliers = hourly_aggregated[(hourly_aggregated['ride_count'] < lower_bound) | (hourly_aggregated['ride_count'] > upper_bound)]

# %%
outliers
# Out:
# Empty DataFrame
# Columns: [start_hour, ride_count, avg_trip_duration]
# Index: []

# %%
q1=hourly_aggregated['avg_trip_duration'].quantile(0.25)#first Quartile
q3=hourly_aggregated['avg_trip_duration'].quantile(0.75)#third Quartile
iqr = q3-q1

# %%
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# %%
outliers_1 = hourly_aggregated[(hourly_aggregated['avg_trip_duration'] < lower_bound) | (hourly_aggregated['avg_trip_duration'] > upper_bound)]

# %%
# there are outliers!
outliers_1
# Out:
#    start_hour  ride_count  avg_trip_duration
# 5           5         195         605.348718

# %%
#finding outliers in the main dateset
q1=citi_1['trip_duration'].quantile(0.25)#first Quartile
q3=citi_1['trip_duration'].quantile(0.75)#third Quartile
iqr = q3-q1

# %%
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# %%
outliers_2 = citi_1[(citi_1['trip_duration'] < lower_bound) | (citi_1['trip_duration'] > upper_bound)]

# %%
outliers_2
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 day_of_week  start_hour  \
# 27               27            27          27         Thu          16
# 55               55            55          55         Wed          17
# 179             179           179         179         Mon          14
# 183             183           183         183         Tue          10
# 197             197           197         197         Thu          17
# ...             ...           ...         ...         ...         ...
# 42837         42837         42837       42837         Sun          18
# 42902         42902         42902       42902         Tue           7
# 42903         42903         42903       42903         Sun          16
# 42909         42909         42909       42909         Mon          16
# 42969         42969         42969       42969         Wed           8
#
#        start_station_id          start_station_name  start_station_latitude  \
# 27                  471     Grand St & Havemeyer St               40.712868
# 55                  469          Broadway & W 53 St               40.763441
# 179                 342  Columbia St & Rivington St               40.717400
# 183                 391         Clark St & Henry St               40.697601
# 197                2006      Central Park S & 6 Ave               40.765909
# ...                 ...                         ...                     ...
# 42837               448            W 37 St & 10 Ave               40.756604
# 42902               278      Concord St & Bridge St               40.697666
# 42903               242  Flushing Ave & Carlton Ave               40.697883
# 42909               493             W 45 St & 6 Ave               40.756800
# 42969               469          Broadway & W 53 St               40.763441
#
#        start_station_longitude  end_station_id  ... end_station_longitude  \
# 27                  -73.956981             388  ...            -74.002950
# 55                  -73.982681             313  ...            -73.967510
# 179                 -73.980166             342  ...            -73.980166
# 183                 -73.993446             486  ...            -73.988557
# 197                 -73.976342            2006  ...            -73.976342
# ...                        ...             ...  ...                   ...
# 42837               -73.997901             514  ...            -74.002777
# 42902               -73.984764             352  ...            -73.977225
# 42903               -73.973503             526  ...            -73.984907
# 42909               -73.982912             501  ...            -73.971212
# 42969               -73.982681             316  ...            -74.006536
#
#        trip_duration  subscriber  birth_year gender           ride_start  \
# 27              2057  Subscriber      1954.0      1  2013-09-19 16:35:39
# 55              2262  Subscriber      1979.0      2  2013-09-11 17:11:27
# 179             2093  Subscriber      1960.0      2  2013-09-09 14:38:39
# 183             2124  Subscriber      1957.0      1  2013-09-24 10:32:52
# 197             2251  Subscriber      1963.0      1  2013-09-05 17:31:47
# ...              ...         ...         ...    ...                  ...
# 42837           2697  Subscriber      1990.0      2  2013-09-08 18:32:27
# 42902           2252  Subscriber      1976.0      2  2013-09-10 07:47:03
# 42903           2697  Subscriber      1965.0      1  2013-09-22 16:10:00
# 42909           2697  Subscriber      1968.0      1  2013-09-09 16:13:08
# 42969           1944  Subscriber      1971.0      2  2013-09-25 08:07:39
#
#                   ride_end    Trip category ride_start_date  \
# 27     2013-09-19 17:09:56  over 20 minutes      2013-09-19
# 55     2013-09-11 17:49:09  over 20 minutes      2013-09-11
# 179    2013-09-09 15:13:32  over 20 minutes      2013-09-09
# 183    2013-09-24 11:08:16  over 20 minutes      2013-09-24
# 197    2013-09-05 18:09:18  over 20 minutes      2013-09-05
# ...                    ...              ...             ...
# 42837  2013-09-08 19:22:58  over 20 minutes      2013-09-08
# 42902  2013-09-10 08:24:35  over 20 minutes      2013-09-10
# 42903  2013-09-22 17:25:53  over 20 minutes      2013-09-22
# 42909  2013-09-09 17:13:59  over 20 minutes      2013-09-09
# 42969  2013-09-25 08:40:03  over 20 minutes      2013-09-25
#
#           ride_start_time
# 27    2024-07-24 16:35:39
# 55    2024-07-24 17:11:27
# 179   2024-07-24 14:38:39
# 183   2024-07-24 10:32:52
# 197   2024-07-24 17:31:47
# ...                   ...
# 42837 2024-07-24 18:32:27
# 42902 2024-07-24 07:47:03
# 42903 2024-07-24 16:10:00
# 42909 2024-07-24 16:13:08
# 42969 2024-07-24 08:07:39
#
# [1976 rows x 22 columns]

# %%
outliers_2.shape
# Out:
# (1976, 22)

# %%
citi_1.shape
# Out:
# (42993, 22)

# %%
#removing outliers
filtered_citi = citi_1[(citi_1['trip_duration'] >= lower_bound) & (citi_1['trip_duration'] <= upper_bound)]

# %%
filtered_citi.shape
# Out:
# (41017, 22)

# %% [markdown]
# # seeing if there are other variables I want to test

# %%
# day of week and ride count
day_counts = citi_1.groupby('day_of_week')['ride_start_date'].count().reset_index()

# %%
day_counts
# Out:
#   day_of_week  ride_start_date
# 0         Fri             6594
# 1         Mon             6797
# 2         Sat             4965
# 3         Sun             5506
# 4         Thu             6212
# 5         Tue             6429
# 6         Wed             6490

# %%
# day of week ride count and avg trip duration
daily_aggregated = citi_1.groupby('day_of_week').agg({
    'ride_start_date': 'count',          # Count of rides
    'trip_duration': 'mean'              # Average trip duration
}).reset_index()

# %%
daily_aggregated
# Out:
#   day_of_week  ride_start_date  trip_duration
# 0         Fri             6594     764.061723
# 1         Mon             6797     761.585552
# 2         Sat             4965     804.035045
# 3         Sun             5506     814.107701
# 4         Thu             6212     750.656632
# 5         Tue             6429     749.886452
# 6         Wed             6490     763.153621

# %% [markdown]
# # less riders on the weekend but longer rides

# %%
#changing column names
daily_aggregated.rename(columns={'ride_start_date': 'ride_count', 'trip_duration': 'avg_trip_duration'}, inplace=True)

# %%
# ride counts and avg trip duration by day
daily_aggregated.plot(x = 'ride_count', y='avg_trip_duration',style='o') # The style option creates a scatterplot; without it, we only have lines.
plt.title('ride counts and thier duration classified by day ')  
plt.xlabel('ride_count')  
plt.ylabel('avg_trip_duration')  
plt.show()

# %% [markdown]
# # ultimately decided to do rides counts in an hour and trip duration
# # Reshape the variables into NumPy arrays and put them into separate objects.

# %%
X = hourly_aggregated['ride_count'].values.reshape(-1,1)
y = hourly_aggregated['avg_trip_duration'].values.reshape(-1,1)

# %%
X
# Out:
# array([[ 420],
#        [ 266],
#        [ 162],
#        [  96],
#        [  75],
#        [ 195],
#        [ 889],
#        [1980],
#        [3127],
#        [2598],
#        [1827],
#        [1841],
#        [2353],
#        [2408],
#        [2401],
#        [2436],
#        [3046],
#        [4398],
#        [4280],
#        [2930],
#        [1932],
#        [1371],
#        [1159],
#        [ 803]])

# %%
y
# Out:
# array([[748.71666667],
#        [702.65789474],
#        [659.5617284 ],
#        [687.02083333],
#        [667.10666667],
#        [605.34871795],
#        [648.61304837],
#        [727.03838384],
#        [756.59545891],
#        [728.34603541],
#        [745.68472906],
#        [760.06518197],
#        [732.08372291],
#        [748.19684385],
#        [788.49979175],
#        [784.35057471],
#        [809.88345371],
#        [822.30832196],
#        [826.91121495],
#        [782.3105802 ],
#        [776.41252588],
#        [771.61050328],
#        [742.78947368],
#        [730.1992528 ]])

# %%
# Split data into a training set and a test set.

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Create a regression object.

regression = LinearRegression()

# %%
# Fit the regression object onto the training set.

regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict the values of y using X. applying model just to X test

#--By only applying it to the “X_test” data set, you’re telling the model to predict the corresponding y values. Once it does this, you can compare it to the actual y values in the “y_test” data set and determine the accuracy of the model.

y_predicted = regression.predict(X_test)

# %%
# Create a plot that shows the regression line from the model on the test set.

plot_test = plt
plot_test.scatter(X_test, y_test, color='gray', s = 15)
plot_test.plot(X_test, y_predicted, color='red', linewidth =3)
plot_test.title('ride counts and trip duration (Test set)')
plot_test.xlabel('ride_counts')
plot_test.ylabel('average_trip_duration')
plot_test.show()

# %% [markdown]
# # the regression line appears to have a positive regression meaning that the more rides that occur in an occur mean longer average rides.  However while the line is on a positive slope the line isnt that close to the plots

# %%
# Create objects that contain the model summary statistics.

rmse = mean_squared_error(y_test, y_predicted) # This is the mean squared error
r2 = r2_score(y_test, y_predicted) # This is the R2 score.

# %%
# Print the model summary statistics. This is where you evaluate the performance of the model.

print('Slope:' ,regression.coef_)
print('Mean squared error: ', rmse)
print('R2 score: ', r2)
# Out:
# Slope: [[0.03746822]]
# Mean squared error:  901.4575617946236
# R2 score:  -0.4467884687296746

# %%
# Create a dataframe comparing the actual and predicted values of y.

data = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_predicted.flatten()})
data.head(30)
# Out:
#        Actual   Predicted
# 0  760.065182  732.755282
# 1  745.684729  732.230727
# 2  742.789474  707.201956
# 3  788.499792  753.737485
# 4  776.412526  736.164890
# 5  702.657895  673.742836
# 6  748.196844  753.999763
# 7  730.199253  693.863270

# %% [markdown]
# # this model did not perform well  on the test set.  When you compare the actual data with predicted it is pretty far off and we are talking about seconds.  I think another indicator is the MSE score.  Being that signifigantly high I think is an indicator that its not a good relationship

# %% [markdown]
# # possible bias could be rides that were not recorded accurately, whether it was cut short or never logged out and rides were too long.

# %% [markdown]
# # With all of this I think for a linear regression to have 2 numeric variables and have a relationship is tough.  I feel for this data set it is a bit more categorical. rides and days of week or rides and hour.  subscribers being male or female.  age of subscriber. etc.

# %%
# saving to csv
citi_1.to_csv(os.path.join(path, '02 Data','prepared data', 'citi_6.csv'))

# %% [markdown]
# # above i removed outliers with the IQR method so I am doing it all again to see it if reads different

# %%
# running the regression again with a filtered DF
hourly_aggregated_filtered = filtered_citi.groupby('start_hour').agg({
    'ride_start_date': 'count',          # Count of rides
    'trip_duration': 'mean'              # Average trip duration
}).reset_index()

# %%
hourly_aggregated_filtered
# Out:
#     start_hour  ride_start_date  trip_duration
# 0            0              403     677.868486
# 1            1              257     647.210117
# 2            2              158     620.936709
# 3            3               90     584.422222
# 4            4               73     616.589041
# 5            5              191     570.586387
# 6            6              863     598.979143
# 7            7             1908     668.484277
# 8            8             3023     705.284155
# 9            9             2504     668.774760
# 10          10             1759     681.419557
# 11          11             1747     675.744133
# 12          12             2258     666.543401
# 13          13             2306     679.187771
# 14          14             2259     693.548915
# 15          15             2316     705.407599
# 16          16             2866     713.957083
# 17          17             4122     722.178554
# 18          18             4041     741.052215
# 19          19             2817     720.935037
# 20          20             1848     708.226190
# 21          21             1319     707.300986
# 22          22             1109     674.930568
# 23          23              780     686.223077

# %%
#rename columns
hourly_aggregated_filtered.rename(columns={'ride_start_date': 'ride_count', 'trip_duration': 'avg_trip_duration'}, inplace=True)

# %%
#plot with DF set with no outliers
hourly_aggregated_filtered.plot(x = 'ride_count', y='avg_trip_duration',style='o') # The style option creates a scatterplot; without it, we only have lines.
plt.title('ride counts and thier duration classified by hour_no outliers ')  
plt.xlabel('ride_count')  
plt.ylabel('avg_trip_duration')  
plt.show()

# %%
#reshaping values
X_1 = hourly_aggregated_filtered['ride_count'].values.reshape(-1,1)
y_1 = hourly_aggregated_filtered['avg_trip_duration'].values.reshape(-1,1)

# %%
# Split data into a training set and a test set.

X_1_train, X_1_test, y_1_train, y_1_test = train_test_split(X_1, y_1, test_size=0.3, random_state=42)

# %%
# Create a regression object.

regression = LinearRegression()

# %%
# Fit the regression object onto the training set.

regression.fit(X_1_train, y_1_train)
# Out:
# LinearRegression()

# %%
# Predict the values of y using X. applying model just to X test

#--By only applying it to the “X_test” data set, you’re telling the model to predict the corresponding y values. Once it does this, you can compare it to the actual y values in the “y_test” data set and determine the accuracy of the model.

y_1_predicted = regression.predict(X_1_test)

# %%
# Create a plot that shows the regression line from the model on the test set.

plot_test_1 = plt
plot_test_1.scatter(X_1_test, y_1_test, color='gray', s = 15)
plot_test_1.plot(X_1_test, y_1_predicted, color='red', linewidth =3)
plot_test_1.title('ride counts and trip duration no outliers (Test set)')
plot_test_1.xlabel('ride_counts')
plot_test_1.ylabel('average_trip_duration')
plot_test_1.show()

# %% [markdown]
# # still a positive regression.  doesnt look any better visually

# %%
# Create objects that contain the model summary statistics.

rmse = mean_squared_error(y_1_test, y_1_predicted) # This is the mean squared error
r2 = r2_score(y_1_test, y_1_predicted) # This is the R2 score.

# %%
# Print the model summary statistics. This is where you evaluate the performance of the model.

print('Slope:' ,regression.coef_)
print('Mean squared error: ', rmse)
print('R2 score: ', r2)
# Out:
# Slope: [[0.03503481]]
# Mean squared error:  604.4295810846346
# R2 score:  0.21346354916799082

# %% [markdown]
# # i changed the random state to 42 to make it a more organized randomized set and it changed the r2 score

# %%
# Create a dataframe comparing the actual and predicted values of y.

data_1 = pd.DataFrame({'Actual': y_1_test.flatten(), 'Predicted': y_1_predicted.flatten()})
data.head(30)
# Out:
#        Actual   Predicted
# 0  760.065182  732.755282
# 1  745.684729  732.230727
# 2  742.789474  707.201956
# 3  788.499792  753.737485
# 4  776.412526  736.164890
# 5  702.657895  673.742836
# 6  748.196844  753.999763
# 7  730.199253  693.863270

# %%
# no signifigant difference when outliers were removed

# %%
hourly_aggregated_filtered.head()
# Out:
#    start_hour  ride_count  avg_trip_duration
# 0           0         403         677.868486
# 1           1         257         647.210117
# 2           2         158         620.936709
# 3           3          90         584.422222
# 4           4          73         616.589041

# %%
citi_1.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 day_of_week  start_hour  \
# 0             0             0           0         Mon          18
# 1             1             1           1         Thu          18
# 2             2             2           2         Wed          19
# 3             3             3           3         Sat          11
# 4             4             4           4         Fri          22
#
#    start_station_id       start_station_name  start_station_latitude  \
# 0               523          W 38 St & 8 Ave               40.754666
# 1               257  Lispenard St & Broadway               40.719392
# 2               479          9 Ave & W 45 St               40.760193
# 3               527          E 33 St & 1 Ave               40.743156
# 4               293    Lafayette St & E 8 St               40.730287
#
#    start_station_longitude  end_station_id  ... end_station_longitude  \
# 0               -73.991382             334  ...            -73.997262
# 1               -74.002472             236  ...            -73.987140
# 2               -73.991255             513  ...            -73.988639
# 3               -73.974347             441  ...            -73.967416
# 4               -73.990765             432  ...            -73.983799
#
#    trip_duration  subscriber  birth_year gender           ride_start  \
# 0            993  Subscriber      1968.0      2  2013-09-09 18:18:55
# 1            581  Subscriber      1983.0      1  2013-09-12 18:38:53
# 2            361  Subscriber      1989.0      1  2013-09-18 19:44:04
# 3            561  Subscriber      1988.0      2  2013-09-28 11:54:37
# 4            427  Subscriber      1986.0      2  2013-09-27 22:01:01
#
#               ride_end     Trip category ride_start_date     ride_start_time
# 0  2013-09-09 18:35:28     10-20 minutes      2013-09-09 2024-07-24 18:18:55
# 1  2013-09-12 18:48:34  under 10 minutes      2013-09-12 2024-07-24 18:38:53
# 2  2013-09-18 19:50:05  under 10 minutes      2013-09-18 2024-07-24 19:44:04
# 3  2013-09-28 12:03:58  under 10 minutes      2013-09-28 2024-07-24 11:54:37
# 4  2013-09-27 22:08:08  under 10 minutes      2013-09-27 2024-07-24 22:01:01
#
# [5 rows x 22 columns]

# %%
citi_clean=citi_1[['day_of_week','start_hour',
       'start_station_id', 'start_station_name', 'start_station_latitude',
       'start_station_longitude', 'end_station_id', 'end_station_name',
       'end_station_latitude', 'end_station_longitude', 'trip_duration',
       'subscriber', 'birth_year', 'gender', 'ride_start', 'ride_end',
       'Trip category', 'ride_start_date', 'ride_start_time']]

# %%
hourly_aggregated_filtered.head()
# Out:
#    start_hour  ride_count  avg_trip_duration
# 0           0         403         677.868486
# 1           1         257         647.210117
# 2           2         158         620.936709
# 3           3          90         584.422222
# 4           4          73         616.589041

# %%
#changing trip duration from seconds to minutes
hourly_aggregated_filtered['avg_trip_duration_min']=hourly_aggregated_filtered['avg_trip_duration']/60

# %%
hourly_aggregated_filtered
# Out:
#     start_hour  ride_count  avg_trip_duration  avg_trip_duration_min
# 0            0         403         677.868486              11.297808
# 1            1         257         647.210117              10.786835
# 2            2         158         620.936709              10.348945
# 3            3          90         584.422222               9.740370
# 4            4          73         616.589041              10.276484
# 5            5         191         570.586387               9.509773
# 6            6         863         598.979143               9.982986
# 7            7        1908         668.484277              11.141405
# 8            8        3023         705.284155              11.754736
# 9            9        2504         668.774760              11.146246
# 10          10        1759         681.419557              11.356993
# 11          11        1747         675.744133              11.262402
# 12          12        2258         666.543401              11.109057
# 13          13        2306         679.187771              11.319796
# 14          14        2259         693.548915              11.559149
# 15          15        2316         705.407599              11.756793
# 16          16        2866         713.957083              11.899285
# 17          17        4122         722.178554              12.036309
# 18          18        4041         741.052215              12.350870
# 19          19        2817         720.935037              12.015584
# 20          20        1848         708.226190              11.803770
# 21          21        1319         707.300986              11.788350
# 22          22        1109         674.930568              11.248843
# 23          23         780         686.223077              11.437051

# %%
#plot with no outliers
hourly_aggregated_filtered.plot(x = 'avg_trip_duration_min', y='ride_count',style='o') # The style option creates a scatterplot; without it, we only have lines.
plt.title('ride counts and thier duration classified by hour_no outliers ')  
plt.xlabel('avg_trip_duration_minutes')  
plt.ylabel('ride_count')  
plt.show()

# %%
X_1 = hourly_aggregated_filtered['avg_trip_duration_min'].values.reshape(-1,1)
y_1 = hourly_aggregated_filtered['ride_count'].values.reshape(-1,1)

# %%
# Predict the values of y using X. applying model just to X test

#--By only applying it to the “X_test” data set, you’re telling the model to predict the corresponding y values. Once it does this, you can compare it to the actual y values in the “y_test” data set and determine the accuracy of the model.

y_1_predicted = regression.predict(X_1_test)

# %%
# Create a plot that shows the regression line from the model on the test set.

plot_test_1 = plt
plot_test_1.scatter(X_1_test, y_1_test, color='gray', s = 15)
plot_test_1.plot(X_1_test, y_1_predicted, color='red', linewidth =3)
plot_test_1.title('ride counts and trip duration no outliers (Test set)')
plot_test_1.xlabel('avg_trip_duration_min')
plot_test_1.ylabel('ride_counts')
plot_test_1.show()

# %%
# Create objects that contain the model summary statistics.

rmse = mean_squared_error(y_1_test, y_1_predicted) # This is the mean squared error
r2 = r2_score(y_1_test, y_1_predicted) # This is the R2 score.

# %%
# Print the model summary statistics. This is where you evaluate the performance of the model.

print('Slope:' ,regression.coef_)
print('Mean squared error: ', rmse)
print('R2 score: ', r2)
# Out:
# Slope: [[0.03503481]]
# Mean squared error:  604.4295810846346
# R2 score:  0.21346354916799082

# %%
ride_counts.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  start_station_id  \
# 0             0             0           0               523
# 1             1             1           1               257
# 2             2             2           2               479
# 3             3             3           3               527
# 4             4             4           4               293
#
#         start_station_name  start_station_latitude  start_station_longitude  \
# 0          W 38 St & 8 Ave               40.754666               -73.991382
# 1  Lispenard St & Broadway               40.719392               -74.002472
# 2          9 Ave & W 45 St               40.760193               -73.991255
# 3          E 33 St & 1 Ave               40.743156               -73.974347
# 4    Lafayette St & E 8 St               40.730287               -73.990765
#
#    end_station_id     end_station_name  end_station_latitude  ...  \
# 0             334      W 20 St & 7 Ave             40.742388  ...
# 1             236  St Marks Pl & 2 Ave             40.728419  ...
# 2             513     W 56 St & 10 Ave             40.768254  ...
# 3             441      E 52 St & 2 Ave             40.756014  ...
# 4             432    E 7 St & Avenue A             40.726218  ...
#
#    start_hour_14  start_hour_15 start_hour_16  start_hour_17  start_hour_18  \
# 0          False          False         False          False           True
# 1          False          False         False          False           True
# 2          False          False         False          False          False
# 3          False          False         False          False          False
# 4          False          False         False          False          False
#
#   start_hour_19 start_hour_20 start_hour_21 start_hour_22 start_hour_23
# 0         False         False         False         False         False
# 1         False         False         False         False         False
# 2          True         False         False         False         False
# 3         False         False         False         False         False
# 4         False         False         False          True         False
#
# [5 rows x 49 columns]

# %%
X=hourly_aggregated_filtered[['start_hour','avg_trip_duration']]

# %%
import statsmodels.api as sm

# %%
X = sm.add_constant(X)

# %%
y = hourly_aggregated_filtered['ride_count']

# %%
model = sm.OLS(y, X).fit()

# %%
#model regression summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             ride_count   R-squared:                       0.629
# Model:                            OLS   Adj. R-squared:                  0.593
# Method:                 Least Squares   F-statistic:                     17.77
# Date:                Wed, 24 Jul 2024   Prob (F-statistic):           3.04e-05
# Time:                        18:18:17   Log-Likelihood:                -191.95
# No. Observations:                  24   AIC:                             389.9
# Df Residuals:                      21   BIC:                             393.4
# Df Model:                           2
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const             -1.286e+04   3088.690     -4.162      0.000   -1.93e+04   -6432.453
# start_hour           -4.8187     31.523     -0.153      0.880     -70.375      60.737
# avg_trip_duration    21.7457      4.946      4.397      0.000      11.460      32.031
# ==============================================================================
# Omnibus:                        0.851   Durbin-Watson:                   0.678
# Prob(Omnibus):                  0.653   Jarque-Bera (JB):                0.854
# Skew:                          -0.296   Prob(JB):                        0.652
# Kurtosis:                       2.290   Cond. No.                     1.32e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.32e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Define the predictor variable (start_hour) and dependent variables (count and avg_trip_duration)
X = hourly_aggregated_filtered['start_hour']
y_count = hourly_aggregated_filtered['ride_count']
y_avg_duration = hourly_aggregated_filtered['avg_trip_duration']

# %%
X = sm.add_constant(X)

# %%
model_count = sm.OLS(y_count, X).fit()

# %%
model_avg_duration = sm.OLS(y_avg_duration, X).fit()

# %%
print("Model for Count of Rides:")
print(model_count.summary())
print("\nModel for Average Trip Duration:")
print(model_avg_duration.summary())
# Out:
# Model for Count of Rides:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             ride_count   R-squared:                       0.287
# Model:                            OLS   Adj. R-squared:                  0.254
# Method:                 Least Squares   F-statistic:                     8.843
# Date:                Wed, 24 Jul 2024   Prob (F-statistic):            0.00701
# Time:                        18:18:18   Log-Likelihood:                -199.78
# No. Observations:                  24   AIC:                             403.6
# Df Residuals:                      22   BIC:                             405.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        658.2067    412.442      1.596      0.125    -197.145    1513.558
# start_hour    91.3770     30.727      2.974      0.007      27.652     155.102
# ==============================================================================
# Omnibus:                        0.156   Durbin-Watson:                   0.369
# Prob(Omnibus):                  0.925   Jarque-Bera (JB):                0.366
# Skew:                           0.089   Prob(JB):                        0.833
# Kurtosis:                       2.421   Cond. No.                         26.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Model for Average Trip Duration:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      avg_trip_duration   R-squared:                       0.482
# Model:                            OLS   Adj. R-squared:                  0.458
# Method:                 Least Squares   F-statistic:                     20.45
# Date:                Wed, 24 Jul 2024   Prob (F-statistic):           0.000169
# Time:                        18:18:19   Log-Likelihood:                -117.05
# No. Observations:                  24   AIC:                             238.1
# Df Residuals:                      22   BIC:                             240.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        621.4526     13.131     47.327      0.000     594.221     648.685
# start_hour     4.4237      0.978      4.522      0.000       2.395       6.452
# ==============================================================================
# Omnibus:                        1.284   Durbin-Watson:                   0.737
# Prob(Omnibus):                  0.526   Jarque-Bera (JB):                1.018
# Skew:                          -0.480   Prob(JB):                        0.601
# Kurtosis:                       2.691   Cond. No.                         26.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X = hourly_aggregated_filtered[['avg_trip_duration', 'start_hour']]
X = sm.add_constant(X)

# %%
y = hourly_aggregated_filtered['ride_count']

# %%
model = sm.OLS(y, X).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             ride_count   R-squared:                       0.629
# Model:                            OLS   Adj. R-squared:                  0.593
# Method:                 Least Squares   F-statistic:                     17.77
# Date:                Wed, 24 Jul 2024   Prob (F-statistic):           3.04e-05
# Time:                        18:18:20   Log-Likelihood:                -191.95
# No. Observations:                  24   AIC:                             389.9
# Df Residuals:                      21   BIC:                             393.4
# Df Model:                           2
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const             -1.286e+04   3088.690     -4.162      0.000   -1.93e+04   -6432.453
# avg_trip_duration    21.7457      4.946      4.397      0.000      11.460      32.031
# start_hour           -4.8187     31.523     -0.153      0.880     -70.375      60.737
# ==============================================================================
# Omnibus:                        0.851   Durbin-Watson:                   0.678
# Prob(Omnibus):                  0.653   Jarque-Bera (JB):                0.854
# Skew:                          -0.296   Prob(JB):                        0.652
# Kurtosis:                       2.290   Cond. No.                     1.32e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.32e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='avg_trip_duration', y='ride_count', data=hourly_aggregated_filtered, scatter_kws={'s': 50}, label='avg_trip_duration')
sns.regplot(x='start_hour', y='ride_count', data=hourly_aggregated_filtered, scatter_kws={'s': 50}, label='start_hour')
plt.title('Ride Counts vs. Predictors')
plt.xlabel('Predictor Variables')
plt.ylabel('Ride Count')
plt.legend()
plt.show()

# %%
X = hourly_aggregated_filtered[['ride_count', 'start_hour']]
X = sm.add_constant(X)

# %%
y = hourly_aggregated_filtered['avg_trip_duration']

# %%
model = sm.OLS(y, X).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      avg_trip_duration   R-squared:                       0.730
# Model:                            OLS   Adj. R-squared:                  0.704
# Method:                 Least Squares   F-statistic:                     28.41
# Date:                Wed, 24 Jul 2024   Prob (F-statistic):           1.06e-06
# Time:                        18:18:23   Log-Likelihood:                -109.22
# No. Observations:                  24   AIC:                             224.4
# Df Residuals:                      21   BIC:                             228.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        606.9446     10.244     59.248      0.000     585.641     628.248
# ride_count     0.0220      0.005      4.397      0.000       0.012       0.032
# start_hour     2.4096      0.856      2.817      0.010       0.630       4.189
# ==============================================================================
# Omnibus:                        2.990   Durbin-Watson:                   1.046
# Prob(Omnibus):                  0.224   Jarque-Bera (JB):                1.558
# Skew:                           0.080   Prob(JB):                        0.459
# Kurtosis:                       4.238   Cond. No.                     4.26e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.26e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='ride_count', y='avg_trip_duration', data=hourly_aggregated_filtered, scatter_kws={'s': 50}, label='avg_trip_duration')
sns.regplot(x='start_hour', y='avg_trip_duration', data=hourly_aggregated_filtered, scatter_kws={'s': 50}, label='start_hour')
plt.title('avg_trip_duration vs. Predictors')
plt.xlabel('Predictor Variables')
plt.ylabel('avg_trip_duration')
plt.legend()
plt.show()

# %%
# Reshape the variables into NumPy arrays
X_avg_trip_duration = hourly_aggregated_filtered['ride_count'].values
y_avg_trip_duration = hourly_aggregated_filtered['avg_trip_duration'].values

X_start_hour = hourly_aggregated_filtered['start_hour'].values
y_avg_trip_duration = hourly_aggregated_filtered['avg_trip_duration'].values

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x=X_avg_trip_duration, y=y_avg_trip_duration, scatter_kws={'s': 50}, label='avg_trip_duration')
sns.regplot(x=X_start_hour, y=y_avg_trip_duration, scatter_kws={'s': 50}, label='start_hour')
plt.title('avg_trip_duration vs. Predictors')
plt.xlabel('Predictor Variables')
plt.ylabel('avg_trip_duration')
plt.legend()
plt.show()

# %%
X = hourly_aggregated_filtered[['ride_count', 'start_hour']]  
y = hourly_aggregated_filtered['avg_trip_duration']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Create a regression object.

regression = LinearRegression()

# %%
# Fit the regression object onto the training set.

regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict the values of y using X. applying model just to X test

#--By only applying it to the “X_test” data set, you’re telling the model to predict the corresponding y values. Once it does this, you can compare it to the actual y values in the “y_test” data set and determine the accuracy of the model.

y_predicted = regression.predict(X_test)

# %%
# Define the predictor variables (X) and the target variable (y)
X = hourly_aggregated_filtered[['ride_count', 'start_hour']]  
y = hourly_aggregated_filtered['avg_trip_duration']  

# Make sure X and y have the same number of data points
assert len(X) == len(y), "X and y must have the same number of data points"

# %%
y_predicted = fitted_model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[148], line 1
# ----> 1 y_predicted = fitted_model.predict(X_test)
#
# NameError: name 'fitted_model' is not defined

# %%
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of X: (24, 2)
# Shape of y: (24,)

# %%
y
# Out:
# 0     677.868486
# 1     647.210117
# 2     620.936709
# 3     584.422222
# 4     616.589041
# 5     570.586387
# 6     598.979143
# 7     668.484277
# 8     705.284155
# 9     668.774760
# 10    681.419557
# 11    675.744133
# 12    666.543401
# 13    679.187771
# 14    693.548915
# 15    705.407599
# 16    713.957083
# 17    722.178554
# 18    741.052215
# 19    720.935037
# 20    708.226190
# 21    707.300986
# 22    674.930568
# 23    686.223077
# Name: avg_trip_duration, dtype: float64

# %%
X
# Out:
#     ride_count  start_hour
# 0          403           0
# 1          257           1
# 2          158           2
# 3           90           3
# 4           73           4
# 5          191           5
# 6          863           6
# 7         1908           7
# 8         3023           8
# 9         2504           9
# 10        1759          10
# 11        1747          11
# 12        2258          12
# 13        2306          13
# 14        2259          14
# 15        2316          15
# 16        2866          16
# 17        4122          17
# 18        4041          18
# 19        2817          19
# 20        1848          20
# 21        1319          21
# 22        1109          22
# 23         780          23

# %%
citi_1.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 day_of_week  start_hour  \
# 0             0             0           0         Mon          18
# 1             1             1           1         Thu          18
# 2             2             2           2         Wed          19
# 3             3             3           3         Sat          11
# 4             4             4           4         Fri          22
#
#    start_station_id       start_station_name  start_station_latitude  \
# 0               523          W 38 St & 8 Ave               40.754666
# 1               257  Lispenard St & Broadway               40.719392
# 2               479          9 Ave & W 45 St               40.760193
# 3               527          E 33 St & 1 Ave               40.743156
# 4               293    Lafayette St & E 8 St               40.730287
#
#    start_station_longitude  end_station_id  ... end_station_longitude  \
# 0               -73.991382             334  ...            -73.997262
# 1               -74.002472             236  ...            -73.987140
# 2               -73.991255             513  ...            -73.988639
# 3               -73.974347             441  ...            -73.967416
# 4               -73.990765             432  ...            -73.983799
#
#    trip_duration  subscriber  birth_year gender           ride_start  \
# 0            993  Subscriber      1968.0      2  2013-09-09 18:18:55
# 1            581  Subscriber      1983.0      1  2013-09-12 18:38:53
# 2            361  Subscriber      1989.0      1  2013-09-18 19:44:04
# 3            561  Subscriber      1988.0      2  2013-09-28 11:54:37
# 4            427  Subscriber      1986.0      2  2013-09-27 22:01:01
#
#               ride_end     Trip category ride_start_date     ride_start_time
# 0  2013-09-09 18:35:28     10-20 minutes      2013-09-09 2024-07-24 18:18:55
# 1  2013-09-12 18:48:34  under 10 minutes      2013-09-12 2024-07-24 18:38:53
# 2  2013-09-18 19:50:05  under 10 minutes      2013-09-18 2024-07-24 19:44:04
# 3  2013-09-28 12:03:58  under 10 minutes      2013-09-28 2024-07-24 11:54:37
# 4  2013-09-27 22:08:08  under 10 minutes      2013-09-27 2024-07-24 22:01:01
#
# [5 rows x 22 columns]

# %%
citi_1_clean=citi_1[['day_of_week','start_hour',
       'start_station_id', 'start_station_name', 'start_station_latitude',
       'start_station_longitude', 'end_station_id', 'end_station_name',
       'end_station_latitude', 'end_station_longitude', 'trip_duration',
       'subscriber', 'birth_year', 'gender', 'ride_start', 'ride_end',
       'Trip category', 'ride_start_date', 'ride_start_time']]

# %%
citi_1_clean
# Out:
#       day_of_week  start_hour  start_station_id       start_station_name  \
# 0             Mon          18               523          W 38 St & 8 Ave
# 1             Thu          18               257  Lispenard St & Broadway
# 2             Wed          19               479          9 Ave & W 45 St
# 3             Sat          11               527          E 33 St & 1 Ave
# 4             Fri          22               293    Lafayette St & E 8 St
# ...           ...         ...               ...                      ...
# 42988         Sat          15               435          W 21 St & 6 Ave
# 42989         Sun          16               224    Spruce St & Nassau St
# 42990         Sat          17               261     Johnson St & Gold St
# 42991         Sat          18               402       Broadway & E 22 St
# 42992         Mon          21               515         W 43 St & 10 Ave
#
#        start_station_latitude  start_station_longitude  end_station_id  \
# 0                   40.754666               -73.991382             334
# 1                   40.719392               -74.002472             236
# 2                   40.760193               -73.991255             513
# 3                   40.743156               -73.974347             441
# 4                   40.730287               -73.990765             432
# ...                       ...                      ...             ...
# 42988               40.741740               -73.994156             448
# 42989               40.711464               -74.005524             301
# 42990               40.694749               -73.983625             151
# 42991               40.740343               -73.989551             524
# 42992               40.760094               -73.994618             488
#
#                end_station_name  end_station_latitude  end_station_longitude  \
# 0               W 20 St & 7 Ave             40.742388             -73.997262
# 1           St Marks Pl & 2 Ave             40.728419             -73.987140
# 2              W 56 St & 10 Ave             40.768254             -73.988639
# 3               E 52 St & 2 Ave             40.756014             -73.967416
# 4             E 7 St & Avenue A             40.726218             -73.983799
# ...                         ...                   ...                    ...
# 42988          W 37 St & 10 Ave             40.756604             -73.997901
# 42989         E 2 St & Avenue B             40.722174             -73.983688
# 42990  Cleveland Pl & Spring St             40.721816             -73.997203
# 42991           W 43 St & 6 Ave             40.755273             -73.983169
# 42992           W 39 St & 9 Ave             40.756458             -73.993722
#
#        trip_duration  subscriber  birth_year  gender           ride_start  \
# 0                993  Subscriber      1968.0       2  2013-09-09 18:18:55
# 1                581  Subscriber      1983.0       1  2013-09-12 18:38:53
# 2                361  Subscriber      1989.0       1  2013-09-18 19:44:04
# 3                561  Subscriber      1988.0       2  2013-09-28 11:54:37
# 4                427  Subscriber      1986.0       2  2013-09-27 22:01:01
# ...              ...         ...         ...     ...                  ...
# 42988            975  Subscriber      1973.0       1  2013-09-28 15:30:14
# 42989           1541  Subscriber      1975.0       1  2013-09-01 16:27:11
# 42990           1191  Subscriber      1970.0       2  2013-09-14 17:32:26
# 42991           1050  Subscriber      1961.0       2  2013-09-07 18:08:21
# 42992            370  Subscriber      1980.0       2  2013-09-23 21:54:36
#
#                   ride_end     Trip category ride_start_date  \
# 0      2013-09-09 18:35:28     10-20 minutes      2013-09-09
# 1      2013-09-12 18:48:34  under 10 minutes      2013-09-12
# 2      2013-09-18 19:50:05  under 10 minutes      2013-09-18
# 3      2013-09-28 12:03:58  under 10 minutes      2013-09-28
# 4      2013-09-27 22:08:08  under 10 minutes      2013-09-27
# ...                    ...               ...             ...
# 42988  2013-09-28 15:46:29     10-20 minutes      2013-09-28
# 42989  2013-09-01 16:52:52   over 20 minutes      2013-09-01
# 42990  2013-09-14 17:52:17     10-20 minutes      2013-09-14
# 42991  2013-09-07 18:25:51     10-20 minutes      2013-09-07
# 42992  2013-09-23 22:00:46  under 10 minutes      2013-09-23
#
#           ride_start_time
# 0     2024-07-24 18:18:55
# 1     2024-07-24 18:38:53
# 2     2024-07-24 19:44:04
# 3     2024-07-24 11:54:37
# 4     2024-07-24 22:01:01
# ...                   ...
# 42988 2024-07-24 15:30:14
# 42989 2024-07-24 16:27:11
# 42990 2024-07-24 17:32:26
# 42991 2024-07-24 18:08:21
# 42992 2024-07-24 21:54:36
#
# [42993 rows x 19 columns]

# %%
filtered_citi.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 day_of_week  start_hour  \
# 0             0             0           0         Mon          18
# 1             1             1           1         Thu          18
# 2             2             2           2         Wed          19
# 3             3             3           3         Sat          11
# 4             4             4           4         Fri          22
#
#    start_station_id       start_station_name  start_station_latitude  \
# 0               523          W 38 St & 8 Ave               40.754666
# 1               257  Lispenard St & Broadway               40.719392
# 2               479          9 Ave & W 45 St               40.760193
# 3               527          E 33 St & 1 Ave               40.743156
# 4               293    Lafayette St & E 8 St               40.730287
#
#    start_station_longitude  end_station_id  ... end_station_longitude  \
# 0               -73.991382             334  ...            -73.997262
# 1               -74.002472             236  ...            -73.987140
# 2               -73.991255             513  ...            -73.988639
# 3               -73.974347             441  ...            -73.967416
# 4               -73.990765             432  ...            -73.983799
#
#    trip_duration  subscriber  birth_year gender           ride_start  \
# 0            993  Subscriber      1968.0      2  2013-09-09 18:18:55
# 1            581  Subscriber      1983.0      1  2013-09-12 18:38:53
# 2            361  Subscriber      1989.0      1  2013-09-18 19:44:04
# 3            561  Subscriber      1988.0      2  2013-09-28 11:54:37
# 4            427  Subscriber      1986.0      2  2013-09-27 22:01:01
#
#               ride_end     Trip category ride_start_date     ride_start_time
# 0  2013-09-09 18:35:28     10-20 minutes      2013-09-09 2024-07-24 18:18:55
# 1  2013-09-12 18:48:34  under 10 minutes      2013-09-12 2024-07-24 18:38:53
# 2  2013-09-18 19:50:05  under 10 minutes      2013-09-18 2024-07-24 19:44:04
# 3  2013-09-28 12:03:58  under 10 minutes      2013-09-28 2024-07-24 11:54:37
# 4  2013-09-27 22:08:08  under 10 minutes      2013-09-27 2024-07-24 22:01:01
#
# [5 rows x 22 columns]

# %%
citi_1_clean=filtered_citi[['day_of_week','start_hour',
       'start_station_id', 'start_station_name', 'start_station_latitude',
       'start_station_longitude', 'end_station_id', 'end_station_name',
       'end_station_latitude', 'end_station_longitude', 'trip_duration',
       'subscriber', 'birth_year', 'gender', 'ride_start', 'ride_end',
       'Trip category', 'ride_start_date', 'ride_start_time']]

# %%
# saving to csv
citi_1_clean.to_csv(os.path.join(path, '02 Data','prepared data', 'citi_6.csv'))
